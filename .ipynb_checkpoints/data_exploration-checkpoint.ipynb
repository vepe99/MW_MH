# %%
import numpy as np
import pandas 
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import pynbody 
from sklearn.metrics import confusion_matrix

import torch 
import torch.nn as nn
import torch.utils.data as data
import torch.nn.functional as F
from nflows import transforms
from torchvision.transforms.functional import resize
from nflows.transforms.base import Transform

# %% [markdown]
# # Put cataloge (AHF) and simulation (output) in the same folder

# %% [markdown]
# # Load the simuation

# %%
s = pynbody.load('data/g8.26e11/snap_2000/output/8.26e11.02000') #this is a SimSnap
h = s.halos() #this is a cataloghue

# %%
print('number of particles in h[1]:', len(h[1]))
print('number of particles in h[-1]:', len(h[len(h)]))
# Out:
# number of particles in h[1]: 9579299
# number of particles in h[-1]: 50

# %%
s.physical_units()

# %%
h1 = h[1]
print('len star', len(h1.s), '\t', 'len gas', len(h1.g), '\t', 'len dark matter', len(h1.d))
print('total number of particles', (len(h1.s) + len(h1.g) + len(h1.d)))
# Out:
# len star 4171413 	 len gas 1665173 	 len dark matter 3742713
# total number of particles 9579299

# %% [markdown]
# # Plot
# halos must be centered before plotting

# %% [markdown]
# ### Plot of h1 (main halo)

# %%
#Edge on
pynbody.analysis.halo.center(h1,mode='hyb')
pynbody.analysis.angmom.sideon(h[1])
pynbody.plot.image(h1.s, width=100, cmap='Blues')
# Out:
# SimArray([[ 3.212243 ,  3.2004848,  3.1887264, ..., 15.180257 ,
#            15.191456 , 15.202654 ],
#           [ 3.1182637,  3.1068509,  3.0954385, ..., 15.4573765,
#            15.486178 , 15.51498  ],
#           [ 3.0242846,  3.0132174,  3.00215  , ..., 15.734495 ,
#            15.780898 , 15.827303 ],
#           ...,
#           [34.345592 , 37.128746 , 39.911903 , ...,  8.687408 ,
#             8.718007 ,  8.748608 ],
#           [33.75508  , 36.429703 , 39.104324 , ...,  8.492667 ,
#             8.526549 ,  8.560432 ],
#           [33.164566 , 35.730656 , 38.296745 , ...,  8.297926 ,
#             8.335092 ,  8.372257 ]], dtype=float32, 'Msol kpc**-3')

# %%
#Face on
pynbody.analysis.angmom.faceon(h[1])
pynbody.plot.image(h[1].s, width=100, cmap='Blues')
# Out:
# SimArray([[12.840617, 13.337505, 13.834394, ..., 44.800297, 44.363968,
#            43.927643],
#           [12.40819 , 12.901142, 13.394094, ..., 44.65608 , 44.159126,
#            43.662174],
#           [11.975764, 12.46478 , 12.953796, ..., 44.511864, 43.95429 ,
#            43.396706],
#           ...,
#           [41.542957, 40.178925, 38.81489 , ..., 30.910662, 31.384607,
#            31.858541],
#           [42.673637, 41.25366 , 39.833668, ..., 30.825657, 31.263828,
#            31.701998],
#           [43.804314, 42.32838 , 40.852455, ..., 30.74065 , 31.143055,
#            31.545458]], dtype=float32, 'Msol kpc**-3')

# %%
pynbody.analysis.halo.center(h[2],mode='hyb')
pynbody.plot.image(h[2].s, width=100, cmap='Blues')
# Out:
# SimArray([[0.43007308, 0.4338833 , 0.43769357, ..., 0.2307963 ,
#            0.22993687, 0.22907747],
#           [0.43350896, 0.4373766 , 0.44124413, ..., 0.23390332,
#            0.23308101, 0.23225869],
#           [0.43694472, 0.44086975, 0.44479483, ..., 0.23701032,
#            0.23622511, 0.23543991],
#           ...,
#           [0.10232929, 0.10326912, 0.10420895, ..., 0.26487258,
#            0.26433915, 0.26380572],
#           [0.09938686, 0.10028411, 0.10118137, ..., 0.2648963 ,
#            0.2643644 , 0.26383257],
#           [0.09644442, 0.0972991 , 0.09815378, ..., 0.26492006,
#            0.26438972, 0.26385936]], dtype=float32, 'Msol kpc**-3')

# %% [markdown]
# ### Profile of density and circular velocity

# %%
ps = pynbody.analysis.profile.Profile(h1.s, min = 0.01, max = 70, type = 'log')
plt.plot(ps['rbins'], ps['density'])
plt.semilogy()
plt.xlabel(r'$R$ [kpc]')
plt.ylabel(r'$\Sigma$ [M$_\odot$/ kpc$^2$]')
# Out:
# Text(0, 0.5, '$\\Sigma$ [M$_\\odot$/ kpc$^2$]')

# %%
ps = pynbody.analysis.profile.Profile(h1.s, min=0.01, max=70, type='log')
pg = pynbody.analysis.profile.Profile(h1.g, min=0.01, max=70, type='log')
pd = pynbody.analysis.profile.Profile(h1.d, min=0.01, max=70, type='log')
p = pynbody.analysis.profile.Profile(h1, min=0.01, max=70, type='log')

for prof, name in zip([p, pd, pg, ps], ['total', 'dm', 'gas', 'star']):
    plt.plot(prof['rbins'], prof['density'], label=name)
plt.semilogy()
plt.legend()
plt.xlabel(r'$R$ [kpc]')
plt.ylabel(r'$\Sigma$ [M$_\odot$ / kpc$^2$]')
# Out:
# Text(0, 0.5, '$\\Sigma$ [M$_\\odot$ / kpc$^2$]')

# %%
ps = pynbody.analysis.profile.Profile(h1.s, min=0.01, max=70, type='log')
pg = pynbody.analysis.profile.Profile(h1.g, min=0.01, max=70, type='log')
pd = pynbody.analysis.profile.Profile(h1.d, min=0.01, max=70, type='log')
p = pynbody.analysis.profile.Profile(h1, min=0.01, max=70, type='log')

for prof, name in zip([p, pd, pg, ps], ['total', 'dm', 'gas', 'star']):
    plt.plot(prof['rbins'], prof['v_circ'], label=name)
plt.semilogy()
plt.legend()
plt.xlabel(r'$R$ [kpc]')
plt.ylabel(r'$V_{circ}$ [km/s]')
# Out:
# pynbody.analysis.profile : Profile v_circ -- this routine assumes the disk is in the x-y plane
# pynbody.analysis.profile : Profile v_circ -- this routine assumes the disk is in the x-y plane
# pynbody.analysis.profile : Profile v_circ -- this routine assumes the disk is in the x-y plane
# pynbody.analysis.profile : Profile v_circ -- this routine assumes the disk is in the x-y plane
# Text(0, 0.5, '$V_{circ}$ [km/s]')

# %%
print(len(s.halos()))
feh_1 = h[4].s['feh']
len(feh_1)

for i, j in enumerate(s.halos()):
    plt.scatter(i, len(j))
# Out:
# 3139

# %% [markdown]
# # Distribution of the whole simulation (no distinction between different halos)

# %%
print(s.s.loadable_keys())
# Out:
# ['pos', 'metals', 'FeMassFrac', 'timeform', 'iord', 'vel', 'igasorder', 'eps', 'HI', 'HeII', 'mass', 'HeI', 'massform', 'OxMassFrac', 'phi', 'tform']

# %% [markdown]
# ## Fe/H O/H
# Halo Catalogue, AHF is the halo finder

# %%
feh = s.s['feh']
oxh = s.s['oxh']

print(len(s.s))
print(len(feh))
print(len(oxh))

type(feh)
# Out:
# 4235419
# 4235419
# 4235419
# pynbody.array.SimArray

# %%
feh_array = np.array(feh)
oxh_array = np.array(oxh)

#let's take the 99.9 percentile 
percentile_feh = np.percentile(feh_array, 0.1)
percentile_oxh = np.percentile(oxh_array, 0.1)
print(percentile_feh)
print(percentile_oxh)
# Out:
# -2.797880438439376
# -2.9822998404827357

# %%
df = pandas.DataFrame(data=(zip(feh_array[feh_array>percentile_feh], oxh_array[oxh_array>percentile_oxh])),
                  columns= ['Fe/H', 'O/H'])

# %%
fig, (ax0, ax1)= plt.subplots(figsize=(10,5), nrows=1, ncols=2)
df['Fe/H'].hist(ax=ax0, bins = int(np.sqrt(len(df['Fe/H']))), density=True)
ax0.set_xlabel('Fe/H')

df['O/H'].hist(ax=ax1, bins = int(np.sqrt(len(df['O/H']))), density=True)
ax1.set_xlabel('O/H')
# Out:
# Text(0.5, 0, 'O/H')

# %%
sns.jointplot(data=df, x='Fe/H', y='O/H', kind='hist')

# %%
plt.hist2d(df['Fe/H'], df['O/H'], bins=(500, 500), norm=matplotlib.colors.LogNorm(), cmap='Blues')
plt.colorbar()
plt.xlabel('Fe/H')
plt.ylabel('O/H')
plt.show()

# %%
plt.hist2d(h[1].s['FeMassFrac'], h[1].s['OxMassFrac'], bins=(500, 500), norm=matplotlib.colors.LogNorm(), cmap='Blues')
plt.colorbar()

# %% [markdown]
# ## Masform timeform

# %%
mass_form = s.s['massform']
time_form = s.s['timeform']

# %%
plt.hist2d(time_form, mass_form, bins=(500, 500), norm=matplotlib.colors.LogNorm());
plt.colorbar()
plt.xlabel('time form')
plt.ylabel('mass form')
# Out:
# Text(0, 0.5, 'mass form')
